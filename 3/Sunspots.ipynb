# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Sunspots.csv')

# %%
data['Date'] = data['Date'].astype('datetime64')
data = data.set_index('Date')
print(data['Monthly Mean Total Sunspot Number'])
# Out:
# Date
# 1749-01-31     96.7
# 1749-02-28    104.3
# 1749-03-31    116.7
# 1749-04-30     92.8
# 1749-05-31    141.7
#               ...
# 2020-09-30      0.6
# 2020-10-31     14.4
# 2020-11-30     34.0
# 2020-12-31     21.8
# 2021-01-31     10.4
# Name: Monthly Mean Total Sunspot Number, Length: 3265, dtype: float64

# %%
plt.figure(figsize=(40, 20))
plt.plot(data['Monthly Mean Total Sunspot Number'])
plt.show()

# %%
rd = data.rolling(20).mean()
plt.figure(figsize=(30, 10))
plt.plot(data['Monthly Mean Total Sunspot Number'])
plt.plot(rd['Monthly Mean Total Sunspot Number'], color='r')
plt.show()
